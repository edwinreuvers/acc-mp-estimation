# %% [markdown]
# ---
# title: "Simulated data"
# repo-actions: false
# ---

# %% [markdown]
# Details of the *in situ* experimentally measured data on rat gastrocnemius medialis muscle can be found on the [project website](https://edwinreuvers.github.io/publications/rat-gm-ampo/) of the study in which the data was collected.
